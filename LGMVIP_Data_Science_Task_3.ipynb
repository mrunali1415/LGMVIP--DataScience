# %% [markdown]
# <a href="https://colab.research.google.com/github/mrunali1415/LGMVIP--DataScience/blob/main/LGMVIP_Data_Science_Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lets Grow More-Data Science Internship-TASK-3 (Exploratory Data Analysis on Dataset- Terrorism)

# %% [markdown]
# ##1) Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##2) Importing the Dataset

# %%
data = pd.read_csv('/content/GT.csv', encoding ='latin1')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,6,31,33,51,53,54,55,57,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ##3) Exploring the Dataset

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.277560e+05  127756.000000  127756.000000  127756.000000
# mean   1.997321e+11    1997.256904       6.438163      15.387755
# std    1.232693e+09      12.327078       3.428032       8.818207
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.987080e+11    1987.000000       3.000000       8.000000
# 50%    1.996110e+11    1996.000000       6.000000      15.000000
# 75%    2.010030e+11    2010.000000       9.000000      23.000000
# max    2.014020e+11    2014.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  127756.000000  127756.000000  127756.000000  123507.000000
# mean        0.035372     134.953231       6.651954      22.331094
# std         0.184719     118.354426       3.016977      20.278814
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127756 entries, 0 to 127755
# Columns: 135 entries, eventid to related
# dtypes: float64(62), int64(15), object(58)
# memory usage: 131.6+ MB

# %% [markdown]
# ##4) Number of rows and columns

# %%
print(f"{data.shape[0]} rows and {data.shape[1]} columns")
# Out:
# 127756 rows and 135 columns

# %% [markdown]
# ##5) Getting the values of original columns

# %%
col = data.columns.to_list()
print(col)
# Out:
# ['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'cla
# ...

# %% [markdown]
# ##6) Renaming the columns

# %%
df = pd.DataFrame(data, data.rename(columns={ 'success': 'Success', 'location': 'Location', 'iyear':'Year','imonth':'Month','extended':'Extended','iday':'Day','country_txt':'Country',
                   'country': 'Country_code', 'provstate':'State','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target',
                   'nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                   'weaptype1_txt':'Weapon_type','motive':'Motive','city':'City','latitude':'Latitude','longitude':'Longitude'},inplace=True))

# %%
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  Extended resolution  \
# 0  1.970000e+11  1970      7    2        NaN         0        NaN
# 1  1.970000e+11  1970      0    0        NaN         0        NaN
# 2  1.970010e+11  1970      1    0        NaN         0        NaN
# 3  1.970010e+11  1970      1    0        NaN         0        NaN
# 4  1.970010e+11  1970      1    0        NaN         0        NaN
#
#    Country_code             Country  region  ... addnotes scite1 scite2  \
# 0            58  Dominican Republic       2  ...      NaN    NaN    NaN
# 1           130              Mexico       1  ...      NaN    NaN    NaN
# 2           160         Philippines       5  ...      NaN    NaN    NaN
# 3            78              Greece       8  ...      NaN    NaN    NaN
# 4           101               Japan       4  ...      NaN    NaN    NaN
#
#    scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0     NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# ...

# %% [markdown]
# ##7) Checking null values for a particular columns

# %%
#df =  df[['Year','Month','Extended','Day','Country','State','Region','City','Latitude','Longitude','Location','AttackType','Killed','Wounded','Target','Summary','Group','Target_Type','Weapon_Type','Motive','Success']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127756 entries, 0 to 127755
# Columns: 135 entries, eventid to related
# dtypes: float64(62), int64(15), object(58)
# memory usage: 131.6+ MB

# %%
df.isnull().sum()
# Out:
# eventid            0
# Year               0
# Month              0
# Day                0
# approxdate    126393
#                ...
# INT_LOG            1
# INT_IDEO           1
# INT_MISC           1
# INT_ANY            1
# related       112349
# Length: 135, dtype: int64

# %% [markdown]
# ##8) Exploratory Data Analysis on Dataset

# %%
#City with Most Attacks
data['City'].value_counts().to_frame().drop('Unknown').sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color='green')
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=15)
plt.ylabel("Number of attacks",fontsize=15)
plt.title("Top 10 most affected cities",fontsize=20)
plt.show()

# %%
#Country With Most Attacks
plt.subplots(figsize=(20,10))
sns.barplot(data['Country'].value_counts()[:10].index,data['Country'].value_counts()[:10].values,palette='rocket')
plt.title('Top 10 most affected countries', fontsize = 20)
plt.xlabel('Country', fontsize = 15)
plt.ylabel('Number of attacks', fontsize = 15)
plt.xticks(rotation = 50)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Region With Most Attacks
data['Region'].value_counts().to_frame().sort_values('Region',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color='green')
plt.xticks(rotation = 50)
plt.xlabel("Region",fontsize=15)
plt.ylabel("Number of attacks",fontsize=15)
plt.title("Top 10 most affected regions",fontsize=20)
plt.show()

# %%
#Group With Most Attacks
data[['Group','Killed']].groupby(['Group'],axis=0).sum().drop('Unknown').sort_values('Killed',ascending=False).head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title("Top 10 terrorist attack groups",fontsize=20)
plt.xlabel("Terrorist group",fontsize=20)
plt.ylabel("Number of attacks",fontsize=20)
plt.show()

# %%
#Target types with most attacks
plt.subplots(figsize=(20,10))
sns.countplot(data["Target_type"],order=data['Target_type'].value_counts().index,palette="rocket");
plt.xticks(rotation=90)
plt.xlabel("Target type",fontsize=15)
plt.ylabel("Number of attacks",fontsize=15)
plt.title("Most attacked target types",fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Attack Type With Most Attacks
data['AttackType'].value_counts().plot(kind='bar',figsize=(20,10),color='green')
plt.xticks(rotation = 50)
plt.xlabel("Attack Type",fontsize=15)
plt.ylabel("Number of attacks",fontsize=15)
plt.title("Most used attack types",fontsize=20)
plt.show()

# %% [markdown]
# ##Conclusions:-
#
#
# 1.   Most attacked city - Baghdad
# 2.   Most attacked country - Iraq
# 3.   Most attacked region - Middle East and North Africa
# 4.   Terrorist group with most attacks - Islamic State of Iraq and the Levant (ISIL)
# 5.   Most attacked target type - Private Citizens and Property
# 6.   Most used attack type - Bombing/Explosion
# 7.   city with most terrorism
